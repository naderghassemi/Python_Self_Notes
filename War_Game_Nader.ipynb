# %% [markdown]
# # War Game

# %% [markdown]
# In this pieces of codes I am going to simulate the game of war which is a card game.

# %%
import random


Suits={"Hearts","Diamonds", "Clubs", "Spades"}

Ranks={"Two", "Three", "Four", "Five", "Six", "Seven", "Eight", "Nine", "Ten", "Jack", "Queen", "King", "Ace"}

Values= {"Two":2 , "Three":3, "Four":4, "Five":5, "Six":6, "Seven":7, "Eight":8, "Nine":9,
         "Ten":10, "Jack":11, "Queen":12, "King":13, "Ace":14}

# %% [markdown]
# First we are building the card class

# %%
class Card():
    
    def __init__(self,suit,rank):
        self.suit=suit
        self.rank=rank
        self.value=Values[rank]
        
    def __str__(self):
        return self.rank+" of "+ self.suit

# %% [markdown]
# Now we are going to creat our deck class

# %%
class Deck():
    
    def __init__(self):
        self.allcards=[]              # Here we just define the list
        for suit in Suits:
            for rank in Ranks:
                self.allcards.append(Card(suit,rank))    # Here we just create the whole cards
    
    def shuffle(self):
        random.shuffle(self.allcards)               # This shuffles the list of the cards
        
    def deal_one(self):
        return self.allcards.pop()     # Don't forget to use return here

# %% [markdown]
# We can try to see each objecty created but I already test them. Next we are going to create the player objects

# %%
class Player():
    
    def __init__(self, name):  # we allow that each player get a name
        self.name=name
        self.all_cards=[]
        
    def remove_one(self):                             # To release one card to the table 
        return self.all_cards.pop(0)                  # Note that it is arguman of .pop is 0
    
    def addcards(self,newcards):                      # To add newcards to the hand of player
        if type(newcards)==type([]):                  # to check if multiple cards being added then do this
            self.all_cards.extend(newcards)
            ''' we can not use .append bc it makes it [A,B,[newcards]], but .extend make it [A,B,newcards]
            '''
        else:
            self.all_cards.append(newcards)
            
    def __str__(self):
        
        return f"Player {self.name} has {len(self.all_cards)} cards."    # if we print each object, this will show up

# %% [markdown]
# So now it is time to create the players and split the deck between them

# %%
player_one=Player("one")                      #created the first player and name it one
player_two=Player("two")                      #created the first player and name it two

new_deck=Deck()                               # creates new deck

new_deck.shuffle()                            # shuffles the new deck

for i in range(26):                           # we have 54 cards in each deck, it splits between two players
    player_one.addcards(new_deck.deal_one())
    player_two.addcards(new_deck.deal_one())

# %% [markdown]
# Here we can check what kind of cards are in each players hand

# %%
for i in range(26):
    print(player_one.all_cards[i])
    print(player_two.all_cards[i])
# Out:
# Four of Diamonds
# Seven of Hearts
# Five of Hearts
# Jack of Spades
# Eight of Clubs
# Eight of Hearts
# Ace of Hearts
# Four of Clubs
# Two of Diamonds
# Ace of Clubs
# Queen of Hearts
# Four of Spades
# Three of Hearts
# Three of Diamonds
# Jack of Hearts
# Nine of Hearts
# Nine of Clubs
# Ten of Diamonds
# Two of Spades
# Eight of Diamonds
# Three of Clubs
# Nine of Diamonds
# Three of Spades
# Queen of Spades
# Seven of Clubs
# Four of Hearts
# Five of Clubs
# Five of Diamonds
# Eight of Spades
# Six of Spades
# Six of Hearts
# King of Spades
# Two of Clubs
# Queen of Diamonds
# Two of Hearts
# Jack of Clubs
# Ace of Spades
# Ace of Diamonds
# Ten of Clubs
# Queen of Clubs
# Nine of Spades
# King of Diamonds
# Six of Clubs
# Jack of Diamonds
# Ten of Hearts
# Ten of Spades
# Five of Spades
# Seven of Spades
# King of Clubs
# Seven of Diamonds
# King of Hearts
# Six of Diamonds

# %%
game_on=True   # We switch the game on!

# %%
round_num=0
while game_on:
    
    round_num+=1
    print(f"Round {round_num}")
    
    

    
    if len(player_one.all_cards)==0:
        print("Player one is out of cards.PLAYER TWO WINS!")
        game_on=False
        break
        
    elif len(player_two.all_cards)== 0:
        print("Player two is out of cards. PLAYER ONE WINS!")
        game_on=False
        break
        
        
    player_one_cards=[]
    player_one_cards.append(player_one.remove_one())

    player_two_cards=[]
    player_two_cards.append(player_two.remove_one())
    
    
    at_war=True
    
    while at_war:
        
        
        
        if player_one_cards[-1].value > player_two_cards[-1].value:
            print(f"Player one: {player_one_cards[-1]}    Player two: {player_two_cards[-1]}")
            player_one.addcards(player_one_cards)
            player_one.addcards(player_two_cards)
            at_war= False
            
            
        elif player_one_cards[-1].value < player_two_cards[-1].value:
            print(f"Player one: {player_one_cards[-1]}    Player two: {player_two_cards[-1]}")
            player_two.addcards(player_one_cards)
            player_two.addcards(player_two_cards)
            at_war= False
            
            
            
        else:
            
            print("WAR!")
            
            if len(player_one.all_cards) < 4:
                print("Player One unable to play war! Game over at War")
                print("Player Two Wins!")
                game_on=False
                break
                
                
                
            elif len(player_two.all_cards) < 4:
                print("Player Two unaable to play war! Game over at War")
                print("Player One Wins!")
                game_on=False
                break
                
                
            else:
                
                for _ in range(4):
                    player_one_cards.append(player_one.remove_one())
                    player_two_cards.append(player_two.remove_one())
# Out:
# Round 1
# Player one: Four of Diamonds    Player two: Seven of Hearts
# Round 2
# Player one: Five of Hearts    Player two: Jack of Spades
# Round 3
# WAR!
# WAR!
# Player one: Three of Clubs    Player two: Nine of Diamonds
# Round 4
# Player one: Three of Spades    Player two: Queen of Spades
# Round 5
# Player one: Seven of Clubs    Player two: Four of Hearts
# Round 6
# WAR!
# Player one: Two of Hearts    Player two: Jack of Clubs
# Round 7
# WAR!
# WAR!
# Player one: Seven of Clubs    Player two: Four of Diamonds
# Round 8
# Player one: Four of Hearts    Player two: Seven of Hearts
# Round 9
# Player one: Ace of Spades    Player two: Five of Hearts
# Round 10
# Player one: Ten of Clubs    Player two: Jack of Spades
# Round 11
# Player one: Nine of Spades    Player two: Eight of Clubs
# Round 12
# Player one: Six of Clubs    Player two: Ace of Hearts
# Round 13
# Player one: Ten of Hearts    Player two: Two of Diamonds
# Round 14
# Player one: Five of Spades    Player two: Queen of Hearts
# Round 15
# Player one: King of Clubs    Player two: Three of Hearts
# Round 16
# Player one: King of Hearts    Player two: Jack of Hearts
# Round 17
# Player one: Seven of Clubs    Player two: Nine of Clubs
# Round 18
# Player one: Ace of Diamonds    Player two: Two of Spades
# Round 19
# Player one: Queen of Clubs    Player two: Three of Clubs
# Round 20
# Player one: King of Diamonds    Player two: Eight of Hearts
# Round 21
# Player one: Jack of Diamonds    Player two: Four of Clubs
# Round 22
# Player one: Ten of Spades    Player two: Ace of Clubs
# Round 23
# Player one: Seven of Spades    Player two: Four of Spades
# Round 24
# Player one: Seven of Diamonds    Player two: Three of Diamonds
# Round 25
# Player one: Six of Diamonds    Player two: Nine of Hearts
# Round 26
# Player one: Four of Diamonds    Player two: Ten of Diamonds
# Round 27
# Player one: Ace of Spades    Player two: Eight of Diamonds
# Round 28
# Player one: Five of Hearts    Player two: Nine of Diamonds
# Round 29
# Player one: Nine of Spades    Player two: Three of Spades
# Round 30
# Player one: Eight of Clubs    Player two: Queen of Spades
# Round 31
# Player one: Ten of Hearts    Player two: Five of Clubs
# Round 32
# Player one: Two of Diamonds    Player two: Eight of Spades
# Round 33
# Player one: King of Clubs    Player two: Six of Hearts
# Round 34
# Player one: Three of Hearts    Player two: Two of Clubs
# Round 35
# Player one: King of Hearts    Player two: Two of Hearts
# Round 36
# Player one: Jack of Hearts    Player two: Five of Diamonds
# Round 37
# Player one: Ace of Diamonds    Player two: Six of Spades
# Round 38
# Player one: Two of Spades    Player two: King of Spades
# Round 39
# WAR!
# Player one: Jack of Diamonds    Player two: Ten of Clubs
# Round 40
# Player one: Four of Clubs    Player two: Jack of Spades
# Round 41
# Player one: Seven of Spades    Player two: Six of Clubs
# Round 42
# Player one: Four of Spades    Player two: Ace of Hearts
# Round 43
# Player one: Seven of Diamonds    Player two: Five of Spades
# Round 44
# Player one: Three of Diamonds    Player two: Queen of Hearts
# Round 45
# Player one: Ace of Spades    Player two: Seven of Clubs
# Round 46
# Player one: Eight of Diamonds    Player two: Nine of Clubs
# Round 47
# Player one: Nine of Spades    Player two: Ten of Spades
# Round 48
# Player one: Three of Spades    Player two: Ace of Clubs
# Round 49
# Player one: Ten of Hearts    Player two: Six of Diamonds
# Round 50
# Player one: Five of Clubs    Player two: Nine of Hearts
# Round 51
# Player one: King of Clubs    Player two: Four of Diamonds
# Round 52
# Player one: Six of Hearts    Player two: Ten of Diamonds
# Round 53
# Player one: Three of Hearts    Player two: Five of Hearts
# Round 54
# Player one: Two of Clubs    Player two: Nine of Diamonds
# Round 55
# Player one: King of Hearts    Player two: Eight of Clubs
# Round 56
# Player one: Two of Hearts    Player two: Queen of Spades
# Round 57
# Player one: Jack of Hearts    Player two: Two of Diamonds
# Round 58
# Player one: Five of Diamonds    Player two: Eight of Spades
# Round 59
# Player one: Ace of Diamonds    Player two: Two of Spades
# Round 60
# Player one: Six of Spades    Player two: King of Spades
# Round 61
# Player one: Queen of Clubs    Player two: Four of Clubs
# Round 62
# Player one: Three of Clubs    Player two: Jack of Spades
# Round 63
# Player one: King of Diamonds    Player two: Four of Spades
# Round 64
# Player one: Eight of Hearts    Player two: Ace of Hearts
# Round 65
# Player one: Jack of Diamonds    Player two: Three of Diamonds
# Round 66
# WAR!
# WAR!
# Player one: Five of Spades    Player two: Nine of Hearts
# Round 67
# Player one: Ace of Spades    Player two: Six of Hearts
# Round 68
# Player one: Seven of Clubs    Player two: Ten of Diamonds
# Round 69
# Player one: Ten of Hearts    Player two: Three of Hearts
# Round 70
# Player one: Six of Diamonds    Player two: Five of Hearts
# Round 71
# Player one: King of Clubs    Player two: Two of Clubs
# Round 72
# Player one: Four of Diamonds    Player two: Nine of Diamonds
# Round 73
# Player one: King of Hearts    Player two: Two of Hearts
# Round 74
# Player one: Eight of Clubs    Player two: Queen of Spades
# Round 75
# Player one: Jack of Hearts    Player two: Five of Diamonds
# Round 76
# Player one: Two of Diamonds    Player two: Eight of Spades
# Round 77
# Player one: Ace of Diamonds    Player two: Six of Spades
# Round 78
# Player one: Two of Spades    Player two: King of Spades
# Round 79
# Player one: Queen of Clubs    Player two: Three of Clubs
# Round 80
# Player one: Four of Clubs    Player two: Jack of Spades
# Round 81
# Player one: King of Diamonds    Player two: Eight of Hearts
# Round 82
# Player one: Four of Spades    Player two: Ace of Hearts
# Round 83
# Player one: Jack of Diamonds    Player two: Queen of Diamonds
# Round 84
# Player one: Three of Diamonds    Player two: Jack of Clubs
# Round 85
# Player one: Ace of Spades    Player two: Four of Hearts
# Round 86
# Player one: Six of Hearts    Player two: Seven of Hearts
# Round 87
# WAR!
# Player one: King of Clubs    Player two: Five of Spades
# Round 88
# Player one: Two of Clubs    Player two: Queen of Hearts
# Round 89
# Player one: King of Hearts    Player two: Eight of Diamonds
# Round 90
# Player one: Two of Hearts    Player two: Nine of Clubs
# Round 91
# Player one: Jack of Hearts    Player two: Nine of Spades
# Round 92
# Player one: Five of Diamonds    Player two: Ten of Spades
# Round 93
# Player one: Ace of Diamonds    Player two: Three of Spades
# Round 94
# Player one: Six of Spades    Player two: Ace of Clubs
# Round 95
# Player one: Queen of Clubs    Player two: Five of Clubs
# Round 96
# Player one: Three of Clubs    Player two: Nine of Hearts
# Round 97
# Player one: King of Diamonds    Player two: Seven of Clubs
# Round 98
# Player one: Eight of Hearts    Player two: Ten of Diamonds
# Round 99
# Player one: Ace of Spades    Player two: Four of Diamonds
# Round 100
# Player one: Four of Hearts    Player two: Nine of Diamonds
# Round 101
# Player one: Ten of Hearts    Player two: Eight of Clubs
# Round 102
# Player one: Three of Hearts    Player two: Queen of Spades
# Round 103
# Player one: Six of Diamonds    Player two: Two of Diamonds
# Round 104
# Player one: Five of Hearts    Player two: Eight of Spades
# Round 105
# Player one: King of Clubs    Player two: Two of Spades
# Round 106
# Player one: Ten of Clubs    Player two: King of Spades
# Round 107
# Player one: Seven of Spades    Player two: Four of Clubs
# Round 108
# Player one: Six of Clubs    Player two: Jack of Spades
# Round 109
# Player one: Seven of Diamonds    Player two: Four of Spades
# Round 110
# Player one: Five of Spades    Player two: Ace of Hearts
# Round 111
# Player one: King of Hearts    Player two: Jack of Diamonds
# Round 112
# Player one: Eight of Diamonds    Player two: Queen of Diamonds
# Round 113
# Player one: Jack of Hearts    Player two: Three of Diamonds
# Round 114
# Player one: Nine of Spades    Player two: Jack of Clubs
# Round 115
# Player one: Ace of Diamonds    Player two: Six of Hearts
# Round 116
# Player one: Three of Spades    Player two: Seven of Hearts
# Round 117
# Player one: Queen of Clubs    Player two: Two of Clubs
# Round 118
# Player one: Five of Clubs    Player two: Queen of Hearts
# Round 119
# Player one: King of Diamonds    Player two: Two of Hearts
# Round 120
# Player one: Seven of Clubs    Player two: Nine of Clubs
# Round 121
# Player one: Ace of Spades    Player two: Five of Diamonds
# Round 122
# Player one: Four of Diamonds    Player two: Ten of Spades
# Round 123
# Player one: Ten of Hearts    Player two: Six of Spades
# Round 124
# Player one: Eight of Clubs    Player two: Ace of Clubs
# Round 125
# Player one: Six of Diamonds    Player two: Three of Clubs
# Round 126
# Player one: Two of Diamonds    Player two: Nine of Hearts
# Round 127
# Player one: King of Clubs    Player two: Eight of Hearts
# Round 128
# Player one: Two of Spades    Player two: Ten of Diamonds
# Round 129
# Player one: Seven of Spades    Player two: Four of Hearts
# Round 130
# Player one: Four of Clubs    Player two: Nine of Diamonds
# Round 131
# Player one: Seven of Diamonds    Player two: Three of Hearts
# Round 132
# Player one: Four of Spades    Player two: Queen of Spades
# Round 133
# Player one: King of Hearts    Player two: Five of Hearts
# Round 134
# Player one: Jack of Diamonds    Player two: Eight of Spades
# Round 135
# Player one: Jack of Hearts    Player two: Ten of Clubs
# Round 136
# Player one: Three of Diamonds    Player two: King of Spades
# Round 137
# Player one: Ace of Diamonds    Player two: Six of Clubs
# Round 138
# Player one: Six of Hearts    Player two: Jack of Spades
# Round 139
# Player one: Queen of Clubs    Player two: Five of Spades
# Round 140
# Player one: Two of Clubs    Player two: Ace of Hearts
# Round 141
# Player one: King of Diamonds    Player two: Eight of Diamonds
# Round 142
# Player one: Two of Hearts    Player two: Queen of Diamonds
# Round 143
# Player one: Ace of Spades    Player two: Nine of Spades
# Round 144
# Player one: Five of Diamonds    Player two: Jack of Clubs
# Round 145
# Player one: Ten of Hearts    Player two: Three of Spades
# Round 146
# Player one: Six of Spades    Player two: Seven of Hearts
# Round 147
# Player one: Six of Diamonds    Player two: Five of Clubs
# Round 148
# Player one: Three of Clubs    Player two: Queen of Hearts
# Round 149
# Player one: King of Clubs    Player two: Seven of Clubs
# Round 150
# Player one: Eight of Hearts    Player two: Nine of Clubs
# Round 151
# Player one: Seven of Spades    Player two: Four of Diamonds
# Round 152
# Player one: Four of Hearts    Player two: Ten of Spades
# Round 153
# Player one: Seven of Diamonds    Player two: Eight of Clubs
# Round 154
# Player one: Three of Hearts    Player two: Ace of Clubs
# Round 155
# Player one: King of Hearts    Player two: Two of Diamonds
# Round 156
# Player one: Five of Hearts    Player two: Nine of Hearts
# Round 157
# Player one: Jack of Diamonds    Player two: Two of Spades
# Round 158
# Player one: Eight of Spades    Player two: Ten of Diamonds
# Round 159
# Player one: Jack of Hearts    Player two: Four of Clubs
# Round 160
# Player one: Ten of Clubs    Player two: Nine of Diamonds
# Round 161
# Player one: Ace of Diamonds    Player two: Four of Spades
# Round 162
# Player one: Six of Clubs    Player two: Queen of Spades
# Round 163
# Player one: Queen of Clubs    Player two: Three of Diamonds
# Round 164
# Player one: Five of Spades    Player two: King of Spades
# Round 165
# Player one: King of Diamonds    Player two: Six of Hearts
# Round 166
# Player one: Eight of Diamonds    Player two: Jack of Spades
# Round 167
# Player one: Ace of Spades    Player two: Two of Clubs
# Round 168
# Player one: Nine of Spades    Player two: Ace of Hearts
# Round 169
# Player one: Ten of Hearts    Player two: Two of Hearts
# Round 170
# Player one: Three of Spades    Player two: Queen of Diamonds
# Round 171
# Player one: Six of Diamonds    Player two: Five of Diamonds
# Round 172
# Player one: Five of Clubs    Player two: Jack of Clubs
# Round 173
# Player one: King of Clubs    Player two: Six of Spades
# Round 174
# WAR!
# Player one: Two of Diamonds    Player two: Nine of Clubs
# Round 175
# Player one: Jack of Diamonds    Player two: Four of Hearts
# Round 176
# Player one: Two of Spades    Player two: Ten of Spades
# Round 177
# Player one: Jack of Hearts    Player two: Seven of Diamonds
# Round 178
# Player one: Four of Clubs    Player two: Eight of Clubs
# Round 179
# Player one: Ten of Clubs    Player two: Three of Hearts
# Round 180
# Player one: Nine of Diamonds    Player two: Ace of Clubs
# Round 181
# Player one: Ace of Diamonds    Player two: Five of Hearts
# Round 182
# Player one: Four of Spades    Player two: Nine of Hearts
# Round 183
# Player one: Queen of Clubs    Player two: Eight of Spades
# Round 184
# Player one: Three of Diamonds    Player two: Ten of Diamonds
# Round 185
# Player one: King of Diamonds    Player two: Six of Clubs
# Round 186
# Player one: Six of Hearts    Player two: Queen of Spades
# Round 187
# Player one: Ace of Spades    Player two: Five of Spades
# Round 188
# Player one: Two of Clubs    Player two: King of Spades
# Round 189
# Player one: Ten of Hearts    Player two: Eight of Diamonds
# Round 190
# Player one: Two of Hearts    Player two: Jack of Spades
# Round 191
# Player one: Six of Diamonds    Player two: Nine of Spades
# Round 192
# Player one: Five of Diamonds    Player two: Ace of Hearts
# Round 193
# Player one: King of Clubs    Player two: Three of Spades
# Round 194
# Player one: Six of Spades    Player two: Queen of Diamonds
# Round 195
# Player one: Jack of Diamonds    Player two: Five of Clubs
# Round 196
# Player one: Four of Hearts    Player two: Jack of Clubs
# Round 197
# Player one: Jack of Hearts    Player two: Seven of Clubs
# Round 198
# WAR!
# Player one: Five of Hearts    Player two: Seven of Hearts
# Round 199
# Player one: Queen of Clubs    Player two: Three of Clubs
# Round 200
# Player one: Eight of Spades    Player two: Queen of Hearts
# Round 201
# Player one: King of Diamonds    Player two: Eight of Hearts
# Round 202
# Player one: Six of Clubs    Player two: Nine of Clubs
# Round 203
# Player one: Ace of Spades    Player two: Two of Spades
# Round 204
# Player one: Five of Spades    Player two: Ten of Spades
# Round 205
# Player one: Ten of Hearts    Player two: Four of Clubs
# Round 206
# WAR!
# Player one: Five of Clubs    Player two: Nine of Hearts
# Round 207
# Player one: Jack of Hearts    Player two: Three of Diamonds
# Round 208
# Player one: Seven of Clubs    Player two: Ten of Diamonds
# Round 209
# Player one: Queen of Clubs    Player two: Six of Hearts
# Round 210
# Player one: Three of Clubs    Player two: Queen of Spades
# Round 211
# Player one: King of Diamonds    Player two: Two of Clubs
# Round 212
# Player one: Eight of Hearts    Player two: King of Spades
# Round 213
# Player one: Ace of Spades    Player two: Two of Hearts
# Round 214
# Player one: Two of Spades    Player two: Jack of Spades
# Round 215
# Player one: Ten of Hearts    Player two: Six of Diamonds
# Round 216
# Player one: Four of Clubs    Player two: Nine of Spades
# Round 217
# Player one: Jack of Hearts    Player two: Five of Diamonds
# Round 218
# Player one: Three of Diamonds    Player two: Ace of Hearts
# Round 219
# Player one: Queen of Clubs    Player two: Six of Spades
# Round 220
# Player one: Six of Hearts    Player two: Queen of Diamonds
# Round 221
# Player one: King of Diamonds    Player two: Four of Hearts
# Round 222
# Player one: Two of Clubs    Player two: Jack of Clubs
# Round 223
# Player one: Ace of Spades    Player two: Seven of Diamonds
# Round 224
# Player one: Two of Hearts    Player two: Ten of Clubs
# Round 225
# Player one: Ten of Hearts    Player two: Three of Hearts
# Round 226
# Player one: Six of Diamonds    Player two: Ace of Diamonds
# Round 227
# Player one: Jack of Hearts    Player two: Five of Hearts
# Round 228
# Player one: Five of Diamonds    Player two: Seven of Spades
# Round 229
# Player one: Queen of Clubs    Player two: Four of Diamonds
# Round 230
# Player one: Six of Spades    Player two: King of Hearts
# Round 231
# Player one: King of Diamonds    Player two: Two of Diamonds
# Round 232
# Player one: Four of Hearts    Player two: Seven of Hearts
# Round 233
# Player one: Ace of Spades    Player two: Eight of Spades
# Round 234
# Player one: Seven of Diamonds    Player two: Queen of Hearts
# Round 235
# Player one: Ten of Hearts    Player two: Six of Clubs
# Round 236
# Player one: Three of Hearts    Player two: Nine of Clubs
# Round 237
# Player one: Jack of Hearts    Player two: Five of Spades
# Round 238
# Player one: Five of Hearts    Player two: Ten of Spades
# Round 239
# Player one: Queen of Clubs    Player two: Eight of Diamonds
# Round 240
# Player one: Four of Diamonds    Player two: King of Clubs
# Round 241
# Player one: King of Diamonds    Player two: Three of Spades
# Round 242
# Player one: Two of Diamonds    Player two: Jack of Diamonds
# Round 243
# Player one: Ace of Spades    Player two: Five of Clubs
# Round 244
# WAR!
# Player one: Five of Spades    Player two: Nine of Hearts
# Round 245
# Player one: Queen of Clubs    Player two: Seven of Clubs
# Round 246
# Player one: Eight of Diamonds    Player two: Ten of Diamonds
# Round 247
# Player one: King of Diamonds    Player two: Three of Clubs
# Round 248
# Player one: Three of Spades    Player two: Queen of Spades
# Round 249
# Player one: Ace of Spades    Player two: Eight of Hearts
# Round 250
# Player one: Five of Clubs    Player two: King of Spades
# Round 251
# Player one: Queen of Clubs    Player two: Two of Spades
# Round 252
# Player one: Seven of Clubs    Player two: Jack of Spades
# Round 253
# Player one: King of Diamonds    Player two: Four of Clubs
# Round 254
# Player one: Three of Clubs    Player two: Nine of Spades
# Round 255
# Player one: Ace of Spades    Player two: Three of Diamonds
# Round 256
# Player one: Eight of Hearts    Player two: Ace of Hearts
# Round 257
# Player one: Queen of Clubs    Player two: Six of Hearts
# Round 258
# Player one: Two of Spades    Player two: Queen of Diamonds
# Round 259
# Player one: King of Diamonds    Player two: Two of Clubs
# Round 260
# Player one: Four of Clubs    Player two: Jack of Clubs
# Round 261
# Player one: Ace of Spades    Player two: Two of Hearts
# Round 262
# Player one: Three of Diamonds    Player two: Ten of Clubs
# Round 263
# Player one: Queen of Clubs    Player two: Six of Diamonds
# Round 264
# Player one: Six of Hearts    Player two: Ace of Diamonds
# Round 265
# Player one: King of Diamonds    Player two: Five of Diamonds
# Round 266
# Player one: Two of Clubs    Player two: Seven of Spades
# Round 267
# Player one: Ace of Spades    Player two: Six of Spades
# Round 268
# Player one: Two of Hearts    Player two: King of Hearts
# Round 269
# Player one: Queen of Clubs    Player two: Four of Hearts
# Round 270
# Player one: Six of Diamonds    Player two: Seven of Hearts
# Round 271
# Player one: King of Diamonds    Player two: Seven of Diamonds
# Round 272
# Player one: Five of Diamonds    Player two: Queen of Hearts
# Round 273
# Player one: Ace of Spades    Player two: Three of Hearts
# Round 274
# Player one: Six of Spades    Player two: Nine of Clubs
# Round 275
# Player one: Queen of Clubs    Player two: Five of Hearts
# Round 276
# Player one: Four of Hearts    Player two: Ten of Spades
# Round 277
# Player one: King of Diamonds    Player two: Four of Diamonds
# Round 278
# Player one: Seven of Diamonds    Player two: King of Clubs
# Round 279
# Player one: Ace of Spades    Player two: Two of Diamonds
# Round 280
# Player one: Three of Hearts    Player two: Jack of Diamonds
# Round 281
# Player one: Queen of Clubs    Player two: Eight of Spades
# Round 282
# Player one: Five of Hearts    Player two: Ten of Hearts
# Round 283
# Player one: King of Diamonds    Player two: Six of Clubs
# Round 284
# Player one: Four of Diamonds    Player two: Jack of Hearts
# Round 285
# Player one: Ace of Spades    Player two: Five of Spades
# Round 286
# Player one: Two of Diamonds    Player two: Eight of Clubs
# Round 287
# Player one: Queen of Clubs    Player two: Nine of Diamonds
# Round 288
# Player one: Eight of Spades    Player two: Ace of Clubs
# Round 289
# Player one: King of Diamonds    Player two: Four of Spades
# Round 290
# Player one: Six of Clubs    Player two: Nine of Hearts
# Round 291
# Player one: Ace of Spades    Player two: Eight of Diamonds
# Round 292
# Player one: Five of Spades    Player two: Ten of Diamonds
# Round 293
# Player one: Queen of Clubs    Player two: Three of Spades
# Round 294
# Player one: Nine of Diamonds    Player two: Queen of Spades
# Round 295
# Player one: King of Diamonds    Player two: Five of Clubs
# Round 296
# Player one: Four of Spades    Player two: King of Spades
# Round 297
# Player one: Ace of Spades    Player two: Seven of Clubs
# Round 298
# Player one: Eight of Diamonds    Player two: Jack of Spades
# Round 299
# Player one: Queen of Clubs    Player two: Three of Clubs
# Round 300
# Player one: Three of Spades    Player two: Nine of Spades
# Round 301
# Player one: King of Diamonds    Player two: Eight of Hearts
# Round 302
# Player one: Five of Clubs    Player two: Ace of Hearts
# Round 303
# Player one: Ace of Spades    Player two: Two of Spades
# Round 304
# Player one: Seven of Clubs    Player two: Queen of Diamonds
# Round 305
# Player one: Queen of Clubs    Player two: Four of Clubs
# Round 306
# Player one: Three of Clubs    Player two: Jack of Clubs
# Round 307
# Player one: King of Diamonds    Player two: Three of Diamonds
# Round 308
# Player one: Eight of Hearts    Player two: Ten of Clubs
# Round 309
# Player one: Ace of Spades    Player two: Six of Hearts
# Round 310
# Player one: Two of Spades    Player two: Ace of Diamonds
# Round 311
# Player one: Queen of Clubs    Player two: Two of Clubs
# Round 312
# Player one: Four of Clubs    Player two: Seven of Spades
# Round 313
# Player one: King of Diamonds    Player two: Two of Hearts
# Round 314
# Player one: Three of Diamonds    Player two: King of Hearts
# Round 315
# Player one: Ace of Spades    Player two: Six of Diamonds
# Round 316
# Player one: Six of Hearts    Player two: Seven of Hearts
# Round 317
# Player one: Queen of Clubs    Player two: Five of Diamonds
# Round 318
# Player one: Two of Clubs    Player two: Queen of Hearts
# Round 319
# Player one: King of Diamonds    Player two: Six of Spades
# Round 320
# Player one: Two of Hearts    Player two: Nine of Clubs
# Round 321
# Player one: Ace of Spades    Player two: Four of Hearts
# Round 322
# Player one: Six of Diamonds    Player two: Ten of Spades
# Round 323
# Player one: Queen of Clubs    Player two: Seven of Diamonds
# Round 324
# Player one: Five of Diamonds    Player two: King of Clubs
# Round 325
# Player one: King of Diamonds    Player two: Three of Hearts
# Round 326
# Player one: Six of Spades    Player two: Jack of Diamonds
# Round 327
# Player one: Ace of Spades    Player two: Five of Hearts
# Round 328
# Player one: Four of Hearts    Player two: Ten of Hearts
# Round 329
# Player one: Queen of Clubs    Player two: Four of Diamonds
# Round 330
# Player one: Seven of Diamonds    Player two: Jack of Hearts
# Round 331
# Player one: King of Diamonds    Player two: Two of Diamonds
# Round 332
# Player one: Three of Hearts    Player two: Eight of Clubs
# Round 333
# Player one: Ace of Spades    Player two: Eight of Spades
# Round 334
# Player one: Five of Hearts    Player two: Ace of Clubs
# Round 335
# Player one: Queen of Clubs    Player two: Six of Clubs
# Round 336
# Player one: Four of Diamonds    Player two: Nine of Hearts
# Round 337
# Player one: King of Diamonds    Player two: Five of Spades
# Round 338
# Player one: Two of Diamonds    Player two: Ten of Diamonds
# Round 339
# Player one: Ace of Spades    Player two: Nine of Diamonds
# Round 340
# Player one: Eight of Spades    Player two: Queen of Spades
# Round 341
# Player one: Queen of Clubs    Player two: Four of Spades
# Round 342
# Player one: Six of Clubs    Player two: King of Spades
# Round 343
# Player one: King of Diamonds    Player two: Eight of Diamonds
# Round 344
# Player one: Five of Spades    Player two: Jack of Spades
# Round 345
# Player one: Ace of Spades    Player two: Three of Spades
# Round 346
# WAR!
# Player one: Eight of Diamonds    Player two: Queen of Diamonds
# Round 347
# Player one: Ace of Spades    Player two: Three of Clubs
# Round 348
# Player one: Three of Spades    Player two: Jack of Clubs
# Round 349
# Player one: Ace of Spades    Player two: Eight of Hearts
# Round 350
# Player one: Three of Clubs    Player two: Ten of Clubs
# Round 351
# Player one: Ace of Spades    Player two: Two of Spades
# Round 352
# Player one: Eight of Hearts    Player two: Ace of Diamonds
# Round 353
# Player one: Ace of Spades    Player two: Four of Clubs
# Round 354
# Player one: Two of Spades    Player two: Seven of Spades
# Round 355
# Player one: Ace of Spades    Player two: Three of Diamonds
# Round 356
# Player one: Four of Clubs    Player two: King of Hearts
# Round 357
# Player one: Ace of Spades    Player two: Six of Hearts
# Round 358
# Player one: Three of Diamonds    Player two: Seven of Hearts
# Round 359
# Player one: Ace of Spades    Player two: Two of Clubs
# Round 360
# Player one: Six of Hearts    Player two: Queen of Hearts
# Round 361
# Player one: Ace of Spades    Player two: Two of Hearts
# Round 362
# Player one: Two of Clubs    Player two: Nine of Clubs
# Round 363
# Player one: Ace of Spades    Player two: Six of Diamonds
# Round 364
# Player one: Two of Hearts    Player two: Ten of Spades
# Round 365
# Player one: Ace of Spades    Player two: Five of Diamonds
# Round 366
# Player one: Six of Diamonds    Player two: King of Clubs
# Round 367
# Player one: Ace of Spades    Player two: Six of Spades
# Round 368
# Player one: Five of Diamonds    Player two: Jack of Diamonds
# Round 369
# Player one: Ace of Spades    Player two: Four of Hearts
# Round 370
# Player one: Six of Spades    Player two: Ten of Hearts
# Round 371
# Player one: Ace of Spades    Player two: Seven of Diamonds
# Round 372
# Player one: Four of Hearts    Player two: Jack of Hearts
# Round 373
# Player one: Ace of Spades    Player two: Three of Hearts
# Round 374
# Player one: Seven of Diamonds    Player two: Eight of Clubs
# Round 375
# Player one: Ace of Spades    Player two: Five of Hearts
# Round 376
# Player one: Three of Hearts    Player two: Ace of Clubs
# Round 377
# Player one: Ace of Spades    Player two: Four of Diamonds
# Round 378
# Player one: Five of Hearts    Player two: Nine of Hearts
# Round 379
# Player one: Ace of Spades    Player two: Two of Diamonds
# Round 380
# Player one: Four of Diamonds    Player two: Ten of Diamonds
# Round 381
# Player one: Ace of Spades    Player two: Eight of Spades
# Round 382
# Player one: Two of Diamonds    Player two: Queen of Spades
# Round 383
# Player one: Ace of Spades    Player two: Six of Clubs
# Round 384
# Player one: Eight of Spades    Player two: King of Spades
# Round 385
# Player one: Ace of Spades    Player two: Five of Spades
# Round 386
# Player one: Six of Clubs    Player two: Jack of Spades
# Round 387
# Player one: Ace of Spades    Player two: Nine of Diamonds
# Round 388
# Player one: Five of Spades    Player two: Queen of Clubs
# Round 389
# Player one: Ace of Spades    Player two: Four of Spades
# Round 390
# Player one: Nine of Diamonds    Player two: King of Diamonds
# Round 391
# Player one: Ace of Spades    Player two: Eight of Diamonds
# Round 392
# Player one: Four of Spades    Player two: Nine of Spades
# Round 393
# Player one: Ace of Spades    Player two: Five of Clubs
# Round 394
# Player one: Eight of Diamonds    Player two: Ace of Hearts
# Round 395
# Player one: Ace of Spades    Player two: Seven of Clubs
# Round 396
# Player one: Five of Clubs    Player two: Queen of Diamonds
# Round 397
# Player one: Ace of Spades    Player two: Three of Spades
# Round 398
# Player one: Seven of Clubs    Player two: Jack of Clubs
# Round 399
# Player one: Ace of Spades    Player two: Three of Clubs
# Round 400
# Player one: Three of Spades    Player two: Ten of Clubs
# Round 401
# Player one: Ace of Spades    Player two: Eight of Hearts
# Round 402
# Player one: Three of Clubs    Player two: Ace of Diamonds
# Round 403
# Player one: Ace of Spades    Player two: Two of Spades
# Round 404
# Player one: Eight of Hearts    Player two: Seven of Spades
# Round 405
# Player one: Ace of Spades    Player two: Four of Clubs
# Round 406
# Player one: Two of Spades    Player two: King of Hearts
# Round 407
# Player one: Eight of Hearts    Player two: Three of Diamonds
# Round 408
# WAR!
# Player one: Three of Diamonds    Player two: Nine of Clubs
# Round 409
# Player one is out of cards.PLAYER TWO WINS!
